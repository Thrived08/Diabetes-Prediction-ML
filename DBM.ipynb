# %%
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sklearn.preprocessing import scale,StandardScaler
from sklearn.model_selection import train_test_split,GridSearchCV,cross_val_predict
from sklearn.metrics import confusion_matrix,accuracy_score,mean_squared_error,r2_score,roc_auc_score,roc_curve,classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
import warnings
warnings.simplefilter(action='ignore')
sns.set()
plt.style.use("ggplot")
# %matplotlib inline

# %%
df=pd.read_csv("diabetes.csv")
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
# percentage of outcomes
# distribution of outcome
df["Outcome"].value_counts()*100/len(df)
# Out:
# Outcome
# 0    65.104167
# 1    34.895833
# Name: count, dtype: float64

# %%
#plot hist of age
plt.figure(figsize=(4,5))
plt.xlabel('Age',fontsize=10)
plt.ylabel('Count',fontsize=10)
df['Age'].hist(edgecolor='black')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
print("MAX AGE: "+str(df['Age'].max()) )
print("MIN AGE: "+str(df['Age'].min()))
# Out:
# MAX AGE: 81
# MIN AGE: 21

# %%
#Density graph
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='str')

# %%
fig,ax=plt.subplots(4,2,figsize=(10,10))
sns.distplot(df.Pregnancies,bins=20,ax=ax[0,0],color="red")
sns.distplot(df.Glucose,bins=20,ax=ax[0,1],color="red")
sns.distplot(df.BloodPressure,bins=20,ax=ax[1,0],color="red")
sns.distplot(df.SkinThickness,bins=20,ax=ax[1,1],color="red")
sns.distplot(df.Insulin,bins=20,ax=ax[2,0],color="red")
sns.distplot(df.BMI,bins=20,ax=ax[2,1],color="red")
sns.distplot(df.DiabetesPedigreeFunction,bins=20,ax=ax[3,0],color="red")
sns.distplot(df.Age,bins=20,ax=ax[3,1],color="red")
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='str')

# %%
cols = [
    "Pregnancies", "Glucose",
    "BloodPressure", "SkinThickness",
    "Insulin", "BMI",
    "DiabetesPedigreeFunction", "Age"
]

for i in range(0, len(cols), 2):
    print(df.groupby("Outcome").agg({
        cols[i]: ["mean", "min", "max"],
        cols[i+1]: ["mean", "min", "max"]
    }))
    print("-" * 60)
# Out:
#         Pregnancies             Glucose
#                mean min max        mean min  max
# Outcome
# 0          3.298000   0  13  109.980000   0  197
# 1          4.865672   0  17  141.257463   0  199
# ------------------------------------------------------------
#         BloodPressure          SkinThickness
#                  mean min  max          mean min max
# Outcome
# 0           68.184000   0  122     19.664000   0  60
# 1           70.824627   0  114     22.164179   0  99
# ------------------------------------------------------------
#             Insulin                 BMI
#                mean min  max       mean  min   max
# Outcome
# 0         68.792000   0  744  30.304200  0.0  57.3
# 1        100.335821   0  846  35.142537  0.0  67.1
# ------------------------------------------------------------
#         DiabetesPedigreeFunction                      Age
#                             mean    min    max       mean min max
# Outcome
# 0                       0.429734  0.078  2.329  31.190000  21  81
# 1                       0.550500  0.088  2.420  37.067164  21  70
# ------------------------------------------------------------

# %%
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# Glucose                   0.331357  0.221071                  0.137337
# BloodPressure             0.088933  0.281805                  0.041265
# SkinThickness             0.436783  0.392573                  0.183928
# Insulin                   1.000000  0.197859                  0.185071
# BMI                       0.197859  1.000000                  0.140647
# DiabetesPedigreeFunction  0.185071  0.140647                  1.000000
# Age                      -0.042163  0.036242                  0.033561
# Outcome                   0.130548  0.292695                  0.173844
#
#                                Age   Outcome
# Pregnancies               0.544341  0.221898
# Glucose                   0.263514  0.466581
# BloodPressure             0.239528  0.065068
# SkinThickness            -0.113970  0.074752
# Insulin                  -0.042163  0.130548
# BMI                       0.036242  0.292695
# DiabetesPedigreeFunction  0.033561  0.173844
# Age                       1.000000  0.238356
# Outcome                   0.238356  1.000000

# %%
#EDA FINAL PART
f,ax=plt.subplots(figsize=[15,10])
sns.heatmap(df.corr(),annot=True,fmt='.2f',ax=ax,cmap='magma')
ax.set_title("Correlation Matix",fontsize=15)
# Out:
# Text(0.5, 1.0, 'Correlation Matix')

# %%
#DATA PREPROCESSING
df = pd.read_csv("diabetes.csv")

# %%
#REPLACE 0 with NAN
cols = [
    'Pregnancies', 'Glucose', 'BloodPressure',
    'SkinThickness', 'Insulin', 'BMI',
    'DiabetesPedigreeFunction', 'Age'
]

df[cols] = df[cols].replace(0, np.nan)

# %%
df.isnull().sum()
# Out:
# Pregnancies                 111
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          6.0    148.0           72.0           35.0      NaN  33.6
# 1          1.0     85.0           66.0           29.0      NaN  26.6
# 2          8.0    183.0           64.0            NaN      NaN  23.3
# 3          1.0     89.0           66.0           23.0     94.0  28.1
# 4          NaN    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Fill missing values with median based on Outcome

columns = df.columns.drop("Outcome")

for col in columns:
    median_0 = df[df["Outcome"] == 0][col].median()
    median_1 = df[df["Outcome"] == 1][col].median()

    df.loc[(df["Outcome"] == 0) & (df[col].isnull()), col] = median_0
    df.loc[(df["Outcome"] == 1) & (df[col].isnull()), col] = median_1

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          6.0    148.0           72.0           35.0    169.5  33.6
# 1          1.0     85.0           66.0           29.0    102.5  26.6
# 2          8.0    183.0           64.0           32.0    169.5  23.3
# 3          1.0     89.0           66.0           23.0     94.0  28.1
# 4          5.0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#PAIR PLOT
p=sns.pairplot(df,hue="Outcome")

# %%
# Count outliers using IQR

for col in df.columns:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower = Q1 - (1.5 * IQR)
    upper = Q3 + (1.5 * IQR)

    outliers = ((df[col] < lower) | (df[col] > upper)).sum()

    print(col, ":", outliers)
# Out:
# Pregnancies : 14
# Glucose : 0
# BloodPressure : 14
# SkinThickness : 87
# Insulin : 51
# BMI : 8
# DiabetesPedigreeFunction : 29
# Age : 9
# Outcome : 0

# %%
#REMOVE OUTLIER
for col in df.columns:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)

    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    df[col] = df[col].clip(lower, upper)

# %%
cols = df.columns

fig, axes = plt.subplots(nrows=(len(cols)+1)//2, ncols=2, figsize=(12, 12))

axes = axes.flatten()

for i, col in enumerate(cols):
    sns.boxplot(x=df[col], ax=axes[i])
    axes[i].set_title(col)


if len(cols) % 2 != 0:
    fig.delaxes(axes[-1])

plt.tight_layout()
plt.show()

# %%
#FEATURE ENG
bins = [0, 18.5, 25, 30, float("inf")]
labels = ["Underweight", "Normal", "Overweight", "Obese"]

df["NEW_BMI"] = pd.cut(df["BMI"], bins=bins, labels=labels)

# %%
bins = [0, 16, 166, float('inf')]
labels = ["Low", "Normal", "High"]

df["NEW_Insulin"] = pd.cut(df["Insulin"], bins=bins, labels=labels)

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome', 'NEW_BMI',
#        'NEW_Insulin'],
#       dtype='str')

# %%
df[df.filter(regex="^NEW").columns] = df.filter(regex="^NEW").astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\arrays\categorical.py:623, in Categorical.astype(self, dtype, copy)
#     622 try:
# --> 623     new_cats = new_cats.astype(dtype=dtype, copy=copy)
#     624     fill_value = self.categories._na_value
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\arrays\string_.py:946, in StringArray.astype(self, dtype, copy)
#     944     return values
# --> 946 return super().astype(dtype, copy)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\arrays\numpy_.py:280, in NumpyExtensionArray.astype(self, dtype, copy)
#     278     return self
# --> 280 result = astype_array(self._ndarray, dtype=dtype, copy=copy)
#     281 return result
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\dtypes\astype.py:185, in astype_array(values, dtype, copy)
#     184 else:
# --> 185     values = _astype_nansafe(values, dtype, copy=copy)
#     187 # in pandas we don't store numpy str dtypes, so convert to object
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\dtypes\astype.py:134, in _astype_nansafe(arr, dtype, copy, skipna)
#     132 if copy or object in (arr.dtype, dtype):
#     133     # Explicit copy, or required since NumPy can't view from / to object.
# --> 134     return arr.astype(dtype, copy=True)
#     136 return arr.astype(dtype, copy=copy)
#
# ValueError: invalid literal for int() with base 10: 'Underweight'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[132], line 1
# ----> 1 df[df.filter(regex="^NEW").columns] = df.filter(regex="^NEW").astype(int)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\generic.py:6541, in NDFrame.astype(self, dtype, copy, errors)
#    6537             results = [ser.astype(dtype, errors=errors) for _, ser in self.items()]
#    6538
#    6539         else:
#    6540             # else, only a single dtype is given
# -> 6541             new_data = self._mgr.astype(dtype=dtype, errors=errors)
#    6542             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6543             return res.__finalize__(self, method="astype")
#    6544
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\internals\managers.py:614, in BaseBlockManager.astype(self, dtype, errors)
#     613 def astype(self, dtype, errors: str = "raise") -> Self:
# --> 614     return self.apply("astype", dtype=dtype, errors=errors)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\internals\managers.py:445, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     443         applied = b.apply(f, **kwargs)
#     444     else:
# --> 445         applied = getattr(b, f)(**kwargs)
#     446     result_blocks = extend_blocks(applied, result_blocks)
#     448 out = type(self).from_blocks(result_blocks, [ax.view() for ax in self.axes])
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\internals\blocks.py:607, in Block.astype(self, dtype, errors, squeeze)
#     604         raise ValueError("Can not squeeze with more than one column.")
#     605     values = values[0, :]  # type: ignore[call-overload]
# --> 607 new_values = astype_array_safe(values, dtype, errors=errors)
#     609 new_values = maybe_coerce_values(new_values)
#     611 refs = None
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\dtypes\astype.py:240, in astype_array_safe(values, dtype, copy, errors)
#     237     dtype = dtype.numpy_dtype
#     239 try:
# --> 240     new_values = astype_array(values, dtype, copy=copy)
#     241 except (ValueError, TypeError):
#     242     # e.g. _astype_nansafe can fail on object-dtype of strings
#     243     #  trying to convert to float
#     244     if errors == "ignore":
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\dtypes\astype.py:182, in astype_array(values, dtype, copy)
#     178     return values
#     180 if not isinstance(values, np.ndarray):
#     181     # i.e. ExtensionArray
# --> 182     values = values.astype(dtype, copy=copy)
#     184 else:
#     185     values = _astype_nansafe(values, dtype, copy=copy)
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\arrays\categorical.py:634, in Categorical.astype(self, dtype, copy)
#     629     except (
#     630         TypeError,  # downstream error msg for CategoricalIndex is misleading
#     631         ValueError,
#     632     ) as err:
#     633         msg = f"Cannot cast {self.categories.dtype} dtype to {dtype}"
# --> 634         raise ValueError(msg) from err
#     636     result = take_nd(
#     637         new_cats, ensure_platform_int(self._codes), fill_value=fill_value
#     638     )
#     640 return result
#
# ValueError: Cannot cast str dtype to int64

# %%
cat_df = df.filter(regex="^NEW")
cat_df.head()
# Out:
#    NEW_BMI_Normal  NEW_BMI_Overweight  NEW_BMI_Obese  NEW_Insulin_Normal  \
# 0               0                   0              1                   0
# 1               0                   1              0                   1
# 2               1                   0              0                   0
# 3               0                   1              0                   1
# 4               0                   0              1                   0
#
#    NEW_Insulin_High
# 0                 1
# 1                 0
# 2                 1
# 3                 0
# 4                 1

# %%
X = df.drop(["Outcome",
             "NEW_BMI_Normal",
             "NEW_BMI_Overweight",
             "NEW_BMI_Obese",
             "NEW_Insulin_Normal",
             "NEW_Insulin_High"], axis=1)

y = df["Outcome"]

# %%
cols=X.columns
index=X.index
X.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          6.0    148.0           72.0           35.0    169.5  33.6
# 1          1.0     85.0           66.0           29.0    102.5  26.6
# 2          8.0    183.0           64.0           32.0    169.5  23.3
# 3          1.0     89.0           66.0           23.0     94.0  28.1
# 4          5.0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction   Age
# 0                     0.627  50.0
# 1                     0.351  31.0
# 2                     0.672  32.0
# 3                     0.167  21.0
# 4                     1.200  33.0

# %%
from sklearn.preprocessing import RobustScaler

scaler = RobustScaler()

X_scaled = scaler.fit_transform(X)

X_scaled = pd.DataFrame(
    X_scaled,
    columns=X.columns
)

X_scaled.head()
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0         0.75  0.765432          0.000       1.000000  1.000000  0.170330
# 1        -0.50 -0.790123         -0.375       0.142857  0.000000 -0.598901
# 2         1.25  1.629630         -0.500       0.571429  1.000000 -0.961538
# 3        -0.50 -0.691358         -0.375      -0.714286 -0.126866 -0.434066
# 4         0.50  0.493827         -2.000       1.000000  0.977612  1.214286
#
#    DiabetesPedigreeFunction       Age
# 0                  0.665359  1.235294
# 1                 -0.056209  0.117647
# 2                  0.783007  0.176471
# 3                 -0.537255 -0.470588
# 4                  2.163399  0.235294

# %%
X_final = pd.concat([X_scaled, cat_df], axis=1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_final,
    y,
    test_size=0.2,
    random_state=0,
    
)

# %%
sclaer=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
#ML ALGO
#LOGISTIC REG
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
print("Accuracy:", accuracy_score(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8961038961038961
# [[98  9]
#  [ 7 40]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.92      0.92       107
#            1       0.82      0.85      0.83        47
#
#     accuracy                           0.90       154
#    macro avg       0.87      0.88      0.88       154
# weighted avg       0.90      0.90      0.90       154

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(X_train, y_train)
y_pred_nb = nb.predict(X_test)
print(classification_report(y_test, y_pred_nb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.89      0.91       107
#            1       0.77      0.87      0.82        47
#
#     accuracy                           0.88       154
#    macro avg       0.86      0.88      0.87       154
# weighted avg       0.89      0.88      0.88       154
